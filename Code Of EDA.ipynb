# %% [markdown]
# Name:Samiksha Kamble
# Task 01: Data analysis on global terrorism
# Finding out the hot zone in terrorism

# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#reading dataset
df = pd.read_csv("globalterrorismdb_0718dist.csv",encoding="latin1")
df.head()
# Out:
# C:\Users\Samiksha Kamble\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
#shape of dataset
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
drop_col = df.isnull().sum()[df.isnull().sum()>(40/100 * df.shape[0])]
drop_col
# Out:
# approxdate         172452
# resolution         179471
# location           126196
# alternative        152680
# alternative_txt    152680
#                     ...
# nreleased          171291
# addnotes           153402
# scite2             104758
# scite3             138175
# related            156653
# Length: 77, dtype: int64

# %%
drop_col.index
# Out:
# Index(['approxdate', 'resolution', 'location', 'alternative',
#        'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
#        'attacktype3_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gsubname', 'gname2',
#        'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain2',
#        'guncertain3', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim',
#        'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt',
#        'weaptype3', 'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt',
#        'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt',
#        'propextent', 'propextent_txt', 'propvalue', 'propcomment', 'nhostkid',
#        'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom',
#        'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote',
#        'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
#        'scite2', 'scite3', 'related'],
#       dtype='object')

# %%
df.drop(drop_col.index,axis = 1,inplace=True)
df.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country                 0
# country_txt             0
# region                  0
# region_txt              0
# provstate             421
# city                  434
# latitude             4556
# longitude            4557
# specificity             6
# vicinity                0
# summary             66129
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1        10373
# targsubtype1_txt    10373
# corp1               42550
# target1               636
# natlty1              1559
# natlty1_txt          1559
# gname                   0
# guncertain1           380
# individual              0
# nperps              71115
# nperpcap            69489
# claimed             66120
# weaptype1               0
# weaptype1_txt           0
# weapsubtype1        20768
# weapsubtype1_txt    20768
# weapsubtype1  0.039002  0.003534 -0.041871  0.019320  -0.067914 -0.111675
# nkill         0.534375  0.037278  0.141016 -0.016212  -0.002696  0.080787
# nkillus       0.869376  0.420597 -0.000402  0.003936   0.007654  0.005259
# nkillter      0.043307  0.000767  0.594125 -0.026890  -0.018963  0.103751
# nwound        1.000000  0.152278  0.038568 -0.013406  -0.001712  0.014692
# nwoundus      0.152278  1.000000  0.000225  0.004924  -0.000027  0.002343
# nwoundte      0.038568  0.000225  1.000000 -0.012788  -0.010300  0.066046
# property     -0.013406  0.004924 -0.012788  1.000000   0.018890  0.052445
# ishostkid    -0.001712 -0.000027 -0.010300  0.018890   1.000000  0.035463
# INT_LOG       0.014692  0.002343  0.066046  0.052445   0.035463  1.000000
# INT_IDEO      0.015832  0.003007  0.065494  0.047609   0.036875  0.996211
# INT_MISC     -0.003148  0.009961 -0.004359  0.022058   0.017453  0.052537
# INT_ANY       0.010745  0.005703  0.060831  0.065701   0.043566  0.891051
#
#               INT_IDEO  INT_MISC   INT_ANY
# eventid      -0.133252 -0.077852 -0.175605
# iyear        -0.133253 -0.077847 -0.175596
# imonth       -0.002034 -0.002554 -0.006336
# iday         -0.001621 -0.002027 -0.001199
# extended      0.075147  0.027335  0.080767
# country       0.067564  0.207281  0.153118
# region       -0.071917  0.043139 -0.047900
# latitude     -0.094470  0.097652 -0.041530
# longitude     0.002268  0.000371  0.002497
# specificity   0.071333 -0.019197  0.061389
# vicinity      0.015119 -0.008232  0.010325
# crit1         0.089888  0.015692  0.082288
# crit2        -0.023829 -0.012980 -0.027752
# crit3        -0.138251 -0.036112 -0.130216
# doubtterr     0.231789  0.022374  0.168947
# multiple      0.126013 -0.027084  0.095019
# success       0.059183 -0.014906  0.038245
# suicide       0.065882 -0.000879  0.057241
# attacktype1   0.077225  0.010632  0.088711
# targtype1    -0.058010 -0.043492 -0.054497
# targsubtype1 -0.030089 -0.036703 -0.032169
# natlty1       0.050055  0.360373  0.147251
# guncertain1   0.239388 -0.004986  0.211408
# individual   -0.048542  0.005490 -0.037488
# nperps        0.018407  0.004647  0.021176
# nperpcap      0.001140  0.022354  0.003725
# claimed       0.171639  0.015228  0.153785
# weaptype1     0.074702 -0.011652  0.084257
# weapsubtype1 -0.109029  0.003272 -0.095745
# nkill         0.083884 -0.014522  0.068140
# nkillus       0.006123  0.005230  0.007858
# nkillter      0.106814 -0.001387  0.098268
# nwound        0.015832 -0.003148  0.010745
# nwoundus      0.003007  0.009961  0.005703
# nwoundte      0.065494 -0.004359  0.060831
# property      0.047609  0.022058  0.065701
# ishostkid     0.036875  0.017453  0.043566
# INT_LOG       0.996211  0.052537  0.891051
# INT_IDEO      1.000000  0.082014  0.893811
# INT_MISC      0.082014  1.000000  0.252193
# INT_ANY       0.893811  0.252193  1.000000
#
# [41 rows x 41 columns]

# %%
country=pd.DataFrame(df["country_txt"].value_counts())
print("Countries that are most affected by attacks:\n")
country.head(7)
# Out:
# Countries that are most affected by attacks:
#              country_txt
# Iraq               24636
# Pakistan           14368
# Afghanistan        12731
# India              11960
# Colombia            8306
# Philippines         6908
# Peru                6096

# %%
region=pd.DataFrame(df["region_txt"].value_counts())
print("Region that are most affected by attacks:\n")
region.head()
# Out:
# Region that are most affected by attacks:
#                             region_txt
# Middle East & North Africa       50474
# South Asia                       44974
# South America                    18978
# Sub-Saharan Africa               17550
# Western Europe                   16639

# %%
city=pd.DataFrame(df["city"].value_counts())
print("City that are most affected by attacks:\n")
city.head(7)
# Out:
# City that are most affected by attacks:
#           city
# Unknown   9775
# Baghdad   7589
# Karachi   2652
# Lima      2359
# Mosul     2265
# Belfast   2171
# Santiago  1621

# %%
years=pd.DataFrame(df["iyear"].value_counts())
years
# Out:
#       iyear
# 2014  16903
# 2015  14965
# 2016  13587
# 2013  12036
# 2017  10900
# 2012   8522
# 2011   5076
# 1992   5071
# 2010   4826
# 2008   4805
# 2009   4721
# 1991   4683
# 1989   4324
# 1990   3887
# 1988   3721
# 1984   3495
# 1994   3456
# 2007   3242
# 1997   3197
# 1987   3183
# 1995   3081
# 1996   3058
# 1985   2915
# 1983   2870
# 1986   2860
# 2006   2758
# 1979   2662
# 1980   2662
# 1981   2586
# 1982   2544
# 2005   2017
# 2001   1906
# 2000   1814
# 1978   1526
# 1999   1395
# 2002   1333
# 1977   1319
# 2003   1278
# 2004   1166
# 1998    934
# 1976    923
# 1975    740
# 1970    651
# 1974    581
# 1972    568
# 1973    473
# 1971    471

# %%
month=pd.DataFrame(df["imonth"].value_counts())
month
# Out:
#     imonth
# 5    16875
# 7    16268
# 8    15800
# 10   15563
# 6    15359
# 3    15257
# 4    15152
# 1    14936
# 11   14906
# 9    14180
# 2    13879
# 12   13496
# 0       20

# %%
attacks=pd.DataFrame(df["attacktype1_txt"].value_counts())
attacks
# Out:
#                                      attacktype1_txt
# Bombing/Explosion                              88255
# Armed Assault                                  42669
# Assassination                                  19312
# Hostage Taking (Kidnapping)                    11158
# Facility/Infrastructure Attack                 10356
# Unknown                                         7276
# Unarmed Assault                                 1015
# Hostage Taking (Barricade Incident)              991
# Hijacking                                        659

# %%
lat=pd.DataFrame(df["latitude"].value_counts())
lat
# Out:
#             latitude
#  33.303566      7521
#  24.891115      2686
# -11.967368      2401
#  36.354145      2247
#  54.607712      2189
# ...              ...
#  32.956430         1
#  5.626579          1
#  19.343744         1
#  34.793224         1
#  31.979167         1
#
# [48322 rows x 1 columns]

# %%
long=pd.DataFrame(df["longitude"].value_counts())
long
# Out:
#              longitude
#  44.371773        7521
#  67.143311        2686
# -76.978462        2401
#  43.143570        2247
# -5.956210         2189
# ...                ...
#  101.712719          1
#  124.781605          1
#  70.732778           1
#  124.529002          1
#  4.000000            1
#
# [48039 rows x 1 columns]

# %%
target=pd.DataFrame(df["targtype1_txt"].value_counts())
target
# Out:
#                                 targtype1_txt
# Private Citizens & Property             43511
# Military                                27984
# Police                                  24506
# Government (General)                    21283
# Business                                20669
# Transportation                           6799
# Utilities                                6023
# Unknown                                  5898
# Religious Figures/Institutions           4440
# Educational Institution                  4322
# Government (Diplomatic)                  3573
# Terrorists/Non-State Militia             3039
# Journalists & Media                      2948
# Violent Political Party                  1866
# Airports & Aircraft                      1343
# Telecommunication                        1009
# NGO                                       970
# Tourists                                  440
# Maritime                                  351
# Food or Water Supply                      317
# Abortion Related                          263
# Other                                     137

# %%
sub_target=pd.DataFrame(df["targsubtype1_txt"].value_counts())
sub_target.head()
# Out:
#                                                     targsubtype1_txt
# Unnamed Civilian/Unspecified                                   11596
# Police Security Forces/Officers                                11178
# Military Unit/Patrol/Convoy                                     8277
# Military Personnel (soldiers, troops, officers,...              7963
# Government Personnel (excluding police, military)               6610

# %%
weapon=pd.DataFrame(df["weaptype1_txt"].value_counts())
weapon
# Out:
#                                                     weaptype1_txt
# Explosives                                                  92426
# Firearms                                                    58524
# Unknown                                                     15157
# Incendiary                                                  11135
# Melee                                                        3655
# Chemical                                                      321
# Sabotage Equipment                                            141
# Vehicle (not to include vehicle-borne explosive...            136
# Other                                                         114
# Biological                                                     35
# Fake Weapons                                                   33
# Radiological                                                   14

# %%
sub_weapon=pd.DataFrame(df["weapsubtype1_txt"].value_counts())
sub_weapon
# Out:
#                                            weapsubtype1_txt
# Unknown Explosive Type                                44980
# Unknown Gun Type                                      33137
# Automatic or Semi-Automatic Rifle                     17412
# Vehicle                                                9900
# Projectile (rockets, mortars, RPGs, etc.)              9848
# Other Explosive Type                                   7304
# Handgun                                                6704
# Grenade                                                5167
# Landmine                                               4251
# Arson/Fire                                             4141
# Suicide (carried bodily by human being)                3245
# Remote Trigger                                         2719
# Knife or Other Sharp Object                            2585
# Sticky Bomb                                            1594
# Molotov Cocktail/Petrol Bomb                           1239
# Dynamite/TNT                                           1222
# Rifle/Shotgun (non-automatic)                          1175
# Gasoline or Alcohol                                     844
# Time Fuse                                               792
# Pipe Bomb                                               625
# Blunt Object                                            587
# Letter Bomb                                             548
# Hands, Feet, Fists                                      231
# Pressure Trigger                                        219
# Unknown Weapon Type                                     107
# Rope or Other Strangling Device                         103
# Other Gun Type                                           86
# Poisoning                                                83
# Explosive                                                65
# Suffocation                                              10

# %%
df["success"].value_counts()
# Out:
# 1    161632
# 0     20059
# Name: success, dtype: int64

# %%
df["suicide"].value_counts()
# Out:
# 0    175058
# 1      6633
# Name: suicide, dtype: int64

# %% [markdown]
# conclusion:South Asian countries such as Iraq,Afghanistan,Pakistan,India where suffering from global terrorism
# Most affected country:Iraq
# Most affected region:Middle East and North Africa
# Most affected city:Bagdad
# Most affected year:2014
# Most attack type:Bombing and Explosion
# Weapons used:Explosives
# They were succeed more no.of times in their attacks
